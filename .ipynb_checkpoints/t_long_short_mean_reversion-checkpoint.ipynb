# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
from datetime import timedelta
#from utils import ret_metrics, all_strats

# %%
def ret_metrics(daily_ret_df):
    start_date, end_date = daily_ret_df.index[[0,-1]]
    years = (end_date - start_date).days/365
    
    #CGR
    CGR = (1 + daily_ret_df).cumprod() - 1
    CAGR = (CGR[-1] + 1)**(1/years) - 1
    
    #Information Ratios
    sharpe = daily_ret_df.mean()/daily_ret_df.std()
    rolling_sharpe = daily_ret_df.rolling(window=126).mean()/daily_ret_df.rolling(window=126).std()

    #Drawdown
    roll_max = (1+CGR).cummax()
    drawdown = (1+CGR)/roll_max - 1.0
    max_drawdown= drawdown.min()
    drawdown_times = (drawdown < 0).astype(np.int64)
    max_drawdown_duration = drawdown_times.groupby((drawdown_times != drawdown_times.shift()).cumsum()).cumsum().min()
    
    #Win/Loss percentage
    winners = (daily_ret_df > 0).sum() / ((daily_ret_df > 0).sum() + (daily_ret_df < 0).sum())
    losers = (daily_ret_df < 0).sum() / ((daily_ret_df > 0).sum() + (daily_ret_df < 0).sum())
    
    print(f'CAGR: {np.round(100*CAGR,2)}% \nAnnual Sharpe Ratio: {round(252**0.5 * sharpe,2)} \
          \nWin Percetage: {np.round(100*winners, 2)}% \
          \nLoss Percetage: {np.round(100*losers, 2)}% \
          \nMax win: {np.round(100*daily_ret_df.max(),2)}% \
          \nMax Loss: {np.round(100*daily_ret_df.min(),2)}% \
          \nAverage Win/Loss: {np.round(100*daily_ret_df.mean(), 2)}% \
          \nMax Drawdown: {np.round(100*max_drawdown,2)}% \
          \nMax Drawdown Duration: {max_drawdown_duration} \
          \n\n')
    
    CGR.plot()
    plt.title('Cummulative Growth')
    plt.show()
    
    drawdown.plot()
    plt.title('Drawdown')
    plt.show()
    #return drawdown

def all_strats(daily_rets, weights):
    if np.sum(weights) != 1:
        raise ValueError('Weights do not add to 1')
    total_daily_rets = 0
    for i in range(len(daily_rets)):
        total_daily_rets = total_daily_rets + daily_rets[i]*weights[i]
    return total_daily_rets

# %% [markdown]
# ### TODO:
# - Get Universe of  Clean Data
# - Research what is not going well with the strategy

# %%
tickers = ""
symbols = pd.read_csv('bats_symbols.csv')['Name']
for symbol in symbols:
    tickers += " " +symbol
tickers = tickers[1:]
data = yf.Tickers(tickers)
history = data.history(start='2015-04-04', end='2017-05-01')
# Out:
# [*********************100%***********************]  518 of 518 completed
#
# 359 Failed downloads:
# - ICOW: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - VFLQ: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - PJUN: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - QMAR: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - LUXE: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - TSOC: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - KOCT: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - VFQY: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - POCT: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - FMIL: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - WDNA: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - RESD: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - IEFN: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - FOCT: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - PBEE: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - XDOC: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - IDME: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - FBCV: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - UFEB: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - PAPR: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - FLBL: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - AMER: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - NUDM: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - STLV: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - BAPR: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - FRDM: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - NJAN: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - TSJA: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - FCTR: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - GSUS: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - FMAY: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - QTAP: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - BFEB: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - FFHG: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - IVSG: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - FFEB: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - EUCG: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - BOCT: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - RDFI: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - FSEP: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - SPMV: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - DUDE: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - AFIF: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - FLQL: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - TOKE: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - DFHY: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - VWID: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - DINT: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - KJUL: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - PSFM: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - BMAR: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# -
Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - LSLT: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - UMAR: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - VFMO: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - SULR: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - SLT: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - PSMJ: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - MIG: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - IBHF: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - FEDX: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - LIV: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - NUEM: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - TTAI: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - TFLT: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - AUGZ: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - MAYZ: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - BALT: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - DEFN: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - WLDR: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - IMFL: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - RYLD: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - PBND: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - GSID: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - DOCT: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - MAMB: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - BBCA: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - BNOV: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - TMDV: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - OCTZ: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - PSEP: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - VOTE: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - NAPR: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - ESHY: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - MDEV: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - HSRT: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - QTOC: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - PSFO: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - PFEB: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - DMAY: Data doesn't exist for startDate = 1428098400, endDate = 1493589600
# - QTJL: Data doesn't exist for startDate = 1428098400, endDate = 1493589600

# %%
#Market ret as mean
cl = history['Close']
ret = cl.pct_change()
ret = ret.drop('BOSS', axis=1)

market_ret = ret.mean(axis=1) #unweighted
weights = - ret.add(- market_ret, axis=0).fillna(0)
ret_threshhold = 0.1
weights[abs(weights) < ret_threshhold] = 0
weights = weights.div(abs(weights).sum(axis=1), axis = 0)

#Dont trade if the daily ret is too high
#inds = abs(market_ret)>0.01
#weights[inds] = 0

dailyret_1 = (weights.shift(1)*ret).sum(axis=1, skipna=True) - 0.015*(abs(weights.diff()).sum(axis=1))
#kelly = 0.25*(dailyret.rolling(window=63).mean()/dailyret.rolling(window=63).var())
#kelly[kelly >= max_leverage] = max_leverage
#dailyret = kelly.shift*(1)*dailyret

ret_metrics(dailyret_1)
# Out:
# CAGR: 52.47%
# Annual Sharpe Ratio: 0.97
# Win Percetage: 56.57%
# Loss Percetage: 43.43%
# Max win: 33.9%
# Max Loss: -35.1%
# Average Win/Loss: 0.26%
# Max Drawdown: -69.49%
# Max Drawdown Duration: 0

# %%
op = history['Open']
cl = history['Close']

ret = (op - cl.shift(1))/cl.shift(1)
ret = ret.drop('BOSS', axis=1)

market_ret = ret.mean(axis=1)
weights = - ret.add(- market_ret, axis=0)
weights = weights.div(abs(weights).sum(axis=1), axis = 0)

dailyret_2 = (weights*(cl-op)/op).sum(axis=1, skipna=True).div(abs(weights).sum(axis=1), axis=0) 

#kelly = 0.25*(dailyret_2.rolling(window=63).mean()/dailyret_2.rolling(window=63).var())
#max_leverage = 4
#kelly[kelly >= max_leverage] = max_leverage
#dailyret = kelly.shift(1)*dailyret

ret_metrics(dailyret_2)
# Out:
# CAGR: nan%
# Annual Sharpe Ratio: 13.44
# Win Percetage: 66.67%
# Loss Percetage: 33.33%
# Max win: 33.63%
# Max Loss: -5.36%
# Average Win/Loss: 17.04%
# Max Drawdown: -5.36%
# Max Drawdown Duration: 0

# %%
dailyrets = all_strats([dailyret_1, dailyret_2], [0.5, 0.5])
ret_metrics(dailyrets.fillna(0))
# Out:
# CAGR: 44.35%
# Annual Sharpe Ratio: 2.42
# Win Percetage: 66.99%
# Loss Percetage: 33.01%
# Max win: 7.32%
# Max Loss: -6.7%
# Average Win/Loss: 0.15%
# Max Drawdown: -10.4%
# Max Drawdown Duration: 0

# %%
#TODO
#Try holding stocks for a longer period
#Try adding mean reversion for multiple days
