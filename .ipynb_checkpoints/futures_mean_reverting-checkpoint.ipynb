# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.ar_model import AutoReg
from statsmodels.api import OLS
import yfinance as yf
from datetime import timedelta

# %%
futures = yf.Tickers("CLX21.NYM CLZ21.NYM CLF22.NYM CLG22.NYM CLH22.NYM CLX22.NYM CL=F")
f_hist = futures.history(start='2020-01-01')
# Out:
# [*********************100%***********************]  7 of 7 completed

# %%
f_hist['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
spot = f_hist['Close']['CL=F']
cl = f_hist['Close'][['CLX21.NYM',  'CLX22.NYM']]
T = [(spot.index[i] - spot.index[0]).days for i in range(1,len(spot))]
spot_model = OLS(np.log(spot[1:]), np.array([T, np.ones(len(T))]).T)
spot_coef = spot_model.fit().params
spot_coef
# Out:
# C:\Users\Tariq\.conda\envs\trading\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# x1      NaN
# const   NaN
# dtype: float64

# %%
gamma = np.zeros(len(cl))*np.nan

for t in range(len(cl)):
    FT = cl.iloc[t]
    T = [i+1 for i in range(len(FT))]
    FT_model = OLS(np.log(FT), np.array([T, np.ones(len(T))]).T)
    FT_coef = FT_model.fit().params
    gamma[t] = -12*FT_coef[0]
gamma = pd.DataFrame(gamma, columns=['gamma'])

# %%
lookback = 40
ma = gamma['gamma'].rolling(lookback).mean()
mstd = gamma['gamma'].rolling(lookback).std()
z_score = (gamma['gamma']-ma)/mstd

# %%
positions = 0 * cl.copy()
z_score.index = positions.index.values

positions['CLX21.NYM'][z_score > 0] = -1
positions['CLX22.NYM'][z_score > 0] = 1

positions['CLX21.NYM'][z_score < 0] = 1
positions['CLX22.NYM'][z_score < 0] = -1


((positions.shift() * cl.pct_change())/2).sum(axis=1).cumsum().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
cl
# Out:
#             CLX21.NYM  CLX22.NYM
# Date
# 2019-12-31  53.240002  51.619999
# 2020-01-02  53.680000  52.020000
# 2020-01-03  53.959999  51.810001
# 2020-01-06  54.110001  51.889999
# 2020-01-07  54.299999  52.209999
# ...               ...        ...
# 2021-09-21  70.489998  64.589996
# 2021-09-22  72.230003  65.870003
# 2021-09-23  73.300003  66.680000
# 2021-09-24  73.980003  67.120003
# 2021-09-27  75.449997  68.849998
#
# [437 rows x 2 columns]

# %%
f_hist['Close'][-1][['CLZ21.NYM', 'CLX21.NYM','CLF22.NYM', 'CLG22.NYM', 'CLX22.NYM'  ]]
# Out:
#                  CL=F  CLF22.NYM  CLG22.NYM  CLH22.NYM  CLX21.NYM  CLX22.NYM  \
# Date
# 2021-09-27  75.449997  74.519997  73.900002  73.309998  75.449997  68.849998
#
#             CLZ21.NYM
# Date
# 2021-09-27  75.080002
